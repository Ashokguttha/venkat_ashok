# %%
import pandas as pd
df = pd.read_csv('test1.csv')
df.head()
# Out:
#    Unnamed: 0 Postcode           Borough     Neighbourhood
# 0           0      M1A      Not assigned      Not assigned
# 1           1      M2A      Not assigned      Not assigned
# 2           2      M3A        North York         Parkwoods
# 3           3      M4A        North York  Victoria Village
# 4           4      M5A  Downtown Toronto      Harbourfront

# %%
df1 = df[df.Borough != 'Not assigned']
df1 = df1.sort_values(by=['Postcode','Borough'])

df1.reset_index(inplace=True)
df1.drop('Unnamed: 0',axis=1,inplace=True)
df1.drop(df1.columns[df1.columns.str.contains('index',case = False)],axis = 1, inplace = True)

df1.head()
# Out:
#   Postcode      Borough   Neighbourhood
# 0      M1B  Scarborough           Rouge
# 1      M1B  Scarborough         Malvern
# 2      M1C  Scarborough  Highland Creek
# 3      M1C  Scarborough      Rouge Hill
# 4      M1C  Scarborough      Port Union

# %%
import geocoder

# %%
def get_latlng(postal_code):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
    return lat_lng_coords
    
get_latlng('M4G')
# Out:
# [43.70949500000006, -79.36398897099997]

# %%
postal_codes = df["Postcode"]    
coords = [ get_latlng(postal_code) for postal_code in postal_codes.tolist() ]

# %%
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
df1['Latitude'] = df_coords['Latitude']
df1['Longitude'] = df_coords['Longitude']
df1.head()
# Out:
#   Postcode      Borough   Neighbourhood   Latitude  Longitude
# 0      M1B  Scarborough           Rouge  43.648690 -79.385440
# 1      M1B  Scarborough         Malvern  43.648690 -79.385440
# 2      M1C  Scarborough  Highland Creek  43.752420 -79.329242
# 3      M1C  Scarborough      Rouge Hill  43.730600 -79.313265
# 4      M1C  Scarborough      Port Union  43.650295 -79.359166

# %%
df1.to_csv('task2.csv', index=False)

# %%
df1
# Out:
#     Postcode       Borough             Neighbourhood   Latitude  Longitude
# 0        M1B   Scarborough                     Rouge  43.648690 -79.385440
# 1        M1B   Scarborough                   Malvern  43.648690 -79.385440
# 2        M1C   Scarborough            Highland Creek  43.752420 -79.329242
# 3        M1C   Scarborough                Rouge Hill  43.730600 -79.313265
# 4        M1C   Scarborough                Port Union  43.650295 -79.359166
# 5        M1E   Scarborough                 Guildwood  43.723270 -79.451286
# 6        M1E   Scarborough               Morningside  43.723270 -79.451286
# 7        M1E   Scarborough                 West Hill  43.661150 -79.391715
# 8        M1G   Scarborough                    Woburn  43.648690 -79.385440
# 9        M1H   Scarborough                 Cedarbrae  43.662299 -79.528195
# 10       M1J   Scarborough       Scarborough Village  43.811525 -79.195517
# ...
